# %% [markdown]
# # Imports

# %%
import librosa
from librosa.display import waveshow, specshow
from librosa.feature import melspectrogram, chroma_stft
import matplotlib.pyplot as plt
import os
import re

# %% [markdown]
# # Setup some music dirs

# %%
music_dir = r'F:\C Backups\Documents\Music\Non-zipped'
music_files = [os.path.join(fpath, file) for fpath, curr_dir, files in os.walk(music_dir) for file in files if re.match(r'.*\.(mp3|m4a|wav)', file)  ]

# %%
music_files[0:20]
# Out:
# ['F:\\C Backups\\Documents\\Music\\Non-zipped\\15 BILLION YEAR OLD BOY.mp3',
#  'F:\\C Backups\\Documents\\Music\\Non-zipped\\Alef - Sol.mp3',
#  'F:\\C Backups\\Documents\\Music\\Non-zipped\\Awakening v2.m4a',
#  'F:\\C Backups\\Documents\\Music\\Non-zipped\\Banshee Barebones.m4a',
#  'F:\\C Backups\\Documents\\Music\\Non-zipped\\Deerob - 117 ft. NLJ (Epic Dubstep Rap).mp3',
#  'F:\\C Backups\\Documents\\Music\\Non-zipped\\Epic Chill Electronica - Helion (NLJ Remix).mp3',
#  'F:\\C Backups\\Documents\\Music\\Non-zipped\\Epic Vocal Electronica - Elliot Berger ft Iain Mannix (NLJ Remix).mp3',
#  'F:\\C Backups\\Documents\\Music\\Non-zipped\\Fall Incredibox mix.wav',
#  'F:\\C Backups\\Documents\\Music\\Non-zipped\\Inspiration v2.m4a',
#  'F:\\C Backups\\Documents\\Music\\Non-zipped\\Lava Tide.mp3',
#  'F:\\C Backups\\Documents\\Music\\Non-zipped\\main beat.wav',
#  'F:\\C Backups\\Documents\\Music\\Non-zipped\\Maxine Sullivan & Her Jazz All-Stars - Memories Of You.mp3',
# ...

# %% [markdown]
# # Play with librosa

# %%
music_files[15]
# Out:
# 'F:\\C Backups\\Documents\\Music\\Non-zipped\\The Speed of Grind v8.wav'

# %%
music_dict = dict()
example_file = music_files[15]
music_dict[example_file] = librosa.load(example_file)

# %%
music_dict[example_file]
# Out:
# (array([-9.0863388e-08,  5.5325125e-07, -3.2867722e-06, ...,
#          6.0141492e-03,  5.3579784e-03,  6.5438594e-03], dtype=float32),
#  22050)

# %%
example_y, example_sr = music_dict[example_file]
example_y, example_sr
# Out:
# (array([-9.0863388e-08,  5.5325125e-07, -3.2867722e-06, ...,
#          6.0141492e-03,  5.3579784e-03,  6.5438594e-03], dtype=float32),
#  22050)

# %%
waveshow(example_y, example_sr)
# Out:
# C:\Users\CFehi\AppData\Local\Temp\ipykernel_44152\2912723486.py:1: FutureWarning: Pass sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   waveshow(example_y, example_sr)

# %%
spect_dict = dict()
spect_dict[example_file] = melspectrogram(example_y, example_sr)
spect_dict[example_file]
# Out:
# C:\Users\CFehi\AppData\Local\Temp\ipykernel_44152\335957920.py:2: FutureWarning: Pass y=[-9.0863388e-08  5.5325125e-07 -3.2867722e-06 ...  6.0141492e-03
#   5.3579784e-03  6.5438594e-03], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spect_dict[example_file] = melspectrogram(example_y, example_sr)
# array([[5.8831811e-06, 9.9078950e-04, 2.5363653e-03, ..., 1.2945761e-03,
#         1.6729806e-03, 5.1185279e-04],
#        [1.9119364e-06, 1.8669452e-04, 2.9239917e-04, ..., 1.0664713e-04,
#         5.5027362e-05, 1.1392374e-04],
#        [1.4128885e-06, 1.1696156e-04, 1.5239116e-04, ..., 2.4987772e-05,
#         1.9173205e-05, 8.4992753e-05],
#        ...,
#        [2.6468777e-05, 8.3891564e-04, 1.6848748e-03, ..., 3.6955413e-07,
#         1.0651451e-06, 3.2675866e-06],
#        [9.2649611e-07, 2.8684015e-05, 9.1442904e-05, ..., 4.9014083e-08,
#         4.1706159e-07, 1.9956553e-06],
# ...

# %%
specshow(spect_dict[example_file], x_axis='s', y_axis='mel')

# %%
chroma_dict = dict()
chroma_dict[example_file] = chroma_stft(example_y, example_sr)
chroma_dict[example_file]
# Out:
# C:\Users\CFehi\AppData\Local\Temp\ipykernel_44152\3472998709.py:2: FutureWarning: Pass y=[-9.0863388e-08  5.5325125e-07 -3.2867722e-06 ...  6.0141492e-03
#   5.3579784e-03  6.5438594e-03], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   chroma_dict[example_file] = chroma_stft(example_y, example_sr)
# array([[0.11854058, 0.10099199, 0.10872722, ..., 0.17011519, 0.1735171 ,
#         0.2467723 ],
#        [0.0965593 , 0.08753221, 0.11574955, ..., 0.16344854, 0.1894297 ,
#         0.28953695],
#        [0.07737017, 0.07319845, 0.07074667, ..., 0.03564753, 0.03907691,
#         0.11008112],
#        ...,
#        [1.        , 1.        , 1.        , ..., 0.21406768, 0.2617994 ,
#         0.40393916],
#        [0.8668026 , 0.8053193 , 0.78573406, ..., 0.4923724 , 0.4983723 ,
#         0.6438501 ],
#        [0.3061983 , 0.3227129 , 0.3318956 , ..., 1.        , 1.        ,
#         1.        ]], dtype=float32)

# %%
specshow(chroma_dict[example_file], x_axis='s', y_axis='chroma')

# %% [markdown]
# # Process and compare some files

# %%
class MusicFile:
    
    def __init__(self, filename: str) -> None:
        self.filename = filename
        self.y, self.sr = librosa.load(filename)
        self.mel_spectrogram = melspectrogram(self.y, self.sr)
        self.chromagram  = chroma_stft(self.y, self.sr)
    
    def show(self):
        self.fig, self.ax = plt.subplots(nrows=3, ncols=1, sharex=True)
        self.fig.suptitle(self.filename.split('\\')[-1])
        self.wave_image = waveshow(self.y, self.sr, ax=self.ax[0])
        self.ax[0].set(title='Envelope view, mono')
        self.ax[0].label_outer()
        
        self.mel_image = specshow(self.mel_spectrogram, x_axis='s', y_axis='mel', ax=self.ax[1])
        self.ax[1].set(title='mel-scaled spectrogram')
        self.ax[1].label_outer()
        
        self.chroma_image = specshow(self.chromagram, x_axis='s', y_axis='chroma', ax=self.ax[2])
        self.ax[2].set(title='chromagram')
        self.ax[2].label_outer()

# %%
MusicFile(music_files[15]).show()
# Out:
# C:\Users\CFehi\AppData\Local\Temp\ipykernel_44152\3739718883.py:6: FutureWarning: Pass y=[-9.0863388e-08  5.5325125e-07 -3.2867722e-06 ...  6.0141492e-03
#   5.3579784e-03  6.5438594e-03], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   self.mel_spectrogram = melspectrogram(self.y, self.sr)
# C:\Users\CFehi\AppData\Local\Temp\ipykernel_44152\3739718883.py:7: FutureWarning: Pass y=[-9.0863388e-08  5.5325125e-07 -3.2867722e-06 ...  6.0141492e-03
#   5.3579784e-03  6.5438594e-03], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   self.chromagram  = chroma_stft(self.y, self.sr)
# C:\Users\CFehi\AppData\Local\Temp\ipykernel_44152\3739718883.py:12: FutureWarning: Pass sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   self.wave_image = waveshow(self.y, self.sr, ax=self.ax[0])

# %%
MusicFile(music_files[0]).show()
# Out:
# d:\ProgramFiles\miniconda3\envs\music\lib\site-packages\librosa\util\decorators.py:88: UserWarning: PySoundFile failed. Trying audioread instead.
#   return f(*args, **kwargs)
# C:\Users\CFehi\AppData\Local\Temp\ipykernel_44152\3739718883.py:6: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   self.mel_spectrogram = melspectrogram(self.y, self.sr)
# C:\Users\CFehi\AppData\Local\Temp\ipykernel_44152\3739718883.py:7: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   self.chromagram  = chroma_stft(self.y, self.sr)
# C:\Users\CFehi\AppData\Local\Temp\ipykernel_44152\3739718883.py:12: FutureWarning: Pass sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   self.wave_image = waveshow(self.y, self.sr, ax=self.ax[0])

# %%
MusicFile(music_files[1]).show()
# Out:
# C:\Users\CFehi\AppData\Local\Temp\ipykernel_44152\3739718883.py:6: FutureWarning: Pass y=[0.01832492 0.02582134 0.01875292 ... 0.00058248 0.00069159 0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   self.mel_spectrogram = melspectrogram(self.y, self.sr)
# C:\Users\CFehi\AppData\Local\Temp\ipykernel_44152\3739718883.py:7: FutureWarning: Pass y=[0.01832492 0.02582134 0.01875292 ... 0.00058248 0.00069159 0.        ], sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   self.chromagram  = chroma_stft(self.y, self.sr)
# C:\Users\CFehi\AppData\Local\Temp\ipykernel_44152\3739718883.py:12: FutureWarning: Pass sr=22050 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   self.wave_image = waveshow(self.y, self.sr, ax=self.ax[0])
